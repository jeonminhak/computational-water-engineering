# %%
def add(a,b)
    return a+b

    add(3, 4)
# Out:
#   Cell In[2], line 1
#     def add(a,b)
#                 ^
# SyntaxError: expected ':'

# %%
def add(a,b)
    returna+b
# Out:
#   Cell In[3], line 1
#     def add(a,b)
#                 ^
# SyntaxError: expected ':'

# %%
def add(a,b)
    return a+b

    add(3,4)
# Out:
#   Cell In[4], line 1
#     def add(a,b)
#                 ^
# SyntaxError: expected ':'

# %%
def add(a,b):
    return a+b
    add(3,4)

# %%
def add(a,b):
    return a+b
add(3,4)
# Out:
# 7
