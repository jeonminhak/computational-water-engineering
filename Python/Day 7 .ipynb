# %%
x = [1, True, 'hello']

# %%
x
# Out:
# [1, True, 'hello']

# %%
x[0]
# Out:
# 1

# %%
x = ['서울','부산','인천','대구','대전','광주','울산','수원']

# %%
x[1]
# Out:
# '부산'

# %%
x[6]
# Out:
# '울산'

# %%
x[0,2,5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 x[0,2,5]
#
# TypeError: list indices must be integers or slices, not tuple

# %%
[x[0], x[2], x[4]]
# Out:
# ['서울', '인천', '대전']

# %%
x[0:3]
# Out:
# ['서울', '부산', '인천']

# %%
x[0:3:2]
# Out:
# ['서울', '인천']

# %%
x[::-1]
# Out:
# ['수원', '울산', '광주', '대전', '대구', '인천', '부산', '서울']
